# %% [markdown]
# # Website information retrieval
#
# In this demo, we will put together a website crawler to retrieve information from a particular website.
# In particular, we will collection information from NLR's Annual Technology Baseline (ATB) website: https://atb.nrel.gov/.
# The information collecting using this technique can be used in downstream model, such as e.g. a chatbot with a knowledge base attuned to the ATB.
#
# ## Website Crawling
#
# The backend technology used for web crawling in ELM is [Crawl4AI](https://github.com/unclecode/crawl4ai). For full control and customization, consider using this library directly.
# Otherwise, if you choose to use the convenience wrapper set up in ELM, you can control the following options:
#
# 1) Which URLs from the webpage to follow and which ones to ignore.
# 2) Which URLs should be prioritized during the crawl.
# 3) Processing for the page content as it is crawled.
# 4) Crawl termination condition, either in the form of a conditional based on the content you have already collected or the total number of pages crawled (or both).
#
#
# ## 1. Basic: 2024 ATB Crawl
#
# Let's begin by putting together the simplest possible crawler:
#
# - No prioritization of URLs
# - Stay within the ATB website
# - Collect all information from all pages visited
# - No extra processing of content
# - Terminate after crawling the whole website
#
#
# We'll start with a few imports:

# %%
import logging
from crawl4ai.deep_crawling.filters import URLFilter
from elm.web.website_crawl import ELMWebsiteCrawler
from elm.web.file_loader import AsyncWebFileLoader

# %% [markdown]
# We'll set the ``elm`` logger to ``DEBUG`` to get a better idea of what is happening as the website is crawled

# %%
logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# Next, we'll need to set up a few utility functions:
#
# - ``empty_link_scorer``:
#     An async scoring function that takes a list of dictionaries (each of
#     which contain information about a link found on the website) and adds
#     a ``"score"`` key that determines the links relevance to our search
#     (the higher the score, the more relevant we think the link is).
#     Since we want to collect all the information from the ATB website,
#     we'll simply return ``1`` as the score for all links. Alternatively,
#     this is the callback we could use to make our search as focused as
#     possible for our use-case.
# - ``empty_validator``:
#     An async validator function that takes an ``elm.web.document.Document``
#     instance and returns whether or not to save this document to the crawl
#     output. Since we want to collect all the information from the ATB website,
#     we'll simply return ``True`` always. Alternatively, this is the callback
#     we could use to decide whether the information from the crawled
#     webpage/document is relevant to our use-case.
# - ``empty_terminator``:
#     An async terminator function that takes a list of ``elm.web.document.Document``
#     instances and returns whether or not to stop the crawl. Since we want to
#     collect all the information from the ATB website, we'll simply return
#     ``False`` always (continue until no more webpages are found). Alternatively,
#     this is the callback we could use to decide whether we have found enough
#     relevant information from the webpage for our use-case.

# %%
async def empty_link_scorer(links):
    """Since we want to collect all the information from the ATB website,
    this scoring function sets the score for all links to 1.
    """
    for link in links:
        link_title_text = link.get("text", "")
        link_url = link.get("href", "")
        # ... compute score ...
        link["score"] = 1

    return links

async def empty_validator(doc):
    """Since we want to collect all the information from the ATB website,
    this validator always returns True.
    """
    return True

async def empty_terminator(docs):
    """Since we want to collect all the information from the ATB website,
    this terminator always returns ``False``.
    """
    return False

# %% [markdown]
# To keep this crawling example focused, we'll only consider the 2024 ATB for now. To do this, we have to set up a URL filter, which will do the following:
#
# - Keep URL's contained to the relevant subdomain (https://atb.nrel.gov) - we don't want to crawl the entire `nrel.gov` domain!
# - If the URL seems to have a year in it (i.e. a ``/20XX``), make sure that we stick with ``/2024``, which includes previous (or future) years.
# - A quirk of the ATB website is that it uses section links within a single web page. This makes the crawler think it is visiting two separate pages, when in reality it is looking at the same page (except in a different location). To get around this, we'll discard any URL's that contain the ``#`` char, which indicates that a section within the page is being linked.
#
# These rules are all combined in an ``apply`` method in a subclass of Crawl4AI's ``URLFilter``:

# %%
class ATBFilter(URLFilter):
    """Helper class to filter url's down to ATB website"""

    def apply(self, url):
        """Check if the URL is part of the ATB website.

        Specifically, we check for the full subdomain (https://atb.nrel.gov)
        in the URL. We also check that if a year is "detected" in the URL,
        that it is the 2024 ATB year. Finally, we check that the URL
        does not contain a section link (i.e., it does not contain a `#`).
        For example, these links

        https://atb.nrel.gov/electricity/2024/index/definitions#financialcases
        https://atb.nrel.gov/electricity/2024/index/definitions#r&donlycase

        are just the same link but pointing to different sections of the
        page. Thus, checking for "#" helps avoid collecting redundant
        information.
        """
        correct_subdomain = url.casefold().startswith("https://atb.nrel.gov")
        correct_year = True if "/20" not in url else "/2024" in url
        not_subsection_link = "#" not in url
        return correct_subdomain and correct_year and not_subsection_link

# %% [markdown]
# Now we instantiate the crawler using our ``empty_link_scorer`` and
# ``empty_validator`` functions. We'll also specify ``{"verify_ssl": False}``
# as ``file_loader_kwargs`` to avoid some SSL issues over the NLR VPN and
# also set ``include_external=False`` (which is actually already the default)
# to prevent the crawl from collecting information from external domains.
# We'll add our own filter that we implemented above using ``extra_url_filters=[ATBFilter()]``,
# and we'll specify that we want the crawl to stop gathering extra links after
# a recursion depth of 3 using the ``crawl_strategy_kwargs={"max_depth": 3}`` input.
# Finally, we will set the ``max_pages`` input to be large enough that we
# can confidently crawl the entire 2024 ATB website.
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Try adding <code>browser_config_kwargs={"headless": False}</code> to the <code>ELMWebsiteCrawler</code> initializer below to visualize the crawl process
# </div>

# %%
afl = AsyncWebFileLoader(verify_ssl=False)
crawler = ELMWebsiteCrawler(empty_validator,
                            async_file_loader=afl,
                            url_scorer=empty_link_scorer,
                            include_external=False,
                            extra_url_filters=[ATBFilter()],
                            crawl_strategy_kwargs={"max_depth": 3},
                            max_pages=1000)

# %% [markdown]
# Now we can pass the ``empty_terminator`` callback as well as our website URL to the ``run`` method
# and watch the logs to track the crawl progress!
#
# <div class="alert alert-block alert-warning">
# <b>Note:</b> Despite the limitations we imposed, the crawl can take still take some time to run (~10 minutes)
# </div>

# %%
atb_info = await crawler.run("https://atb.nrel.gov/",
                             termination_callback=empty_terminator)
# Out:
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/archive
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/search
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/about
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/contact
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/about
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/index
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/index
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/technologies
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/data
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/data
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/about
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/technologies
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/data
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/commercial_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/approach_&_methodology
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/index
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/definitions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/concentrating_solar_power
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/commercial_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/disclaimer
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/nuclear
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/offshore_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/land-based_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/fossil_energy_technologies
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/errata
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/financial_cases_&_methods
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/geothermal
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/hydropower
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/pumped_storage_hydropower
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/technologies
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/technical_limitations
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/utility-scale_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/residential_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/residential_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/utility-scale_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/references
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/utility-scale_pv-plus-battery
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/biopower_(eia)
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/commercial_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/changes_in_2024
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/acronyms
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/commercial_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/approach_&_methodology
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/concentrating_solar_power
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/disclaimer
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/financial_cases_&_methods
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/distributed_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/equations_&_variables
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/errata
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/definitions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/fossil_energy_technologies
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/nuclear
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/geothermal
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/land-based_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/hydropower
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/offshore_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/residential_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/pumped_storage_hydropower
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/residential_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/references
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/technical_limitations
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Aviation_Fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/utility-scale_pv
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/utility-scale_pv-plus-battery
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/utility-scale_battery_storage
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Electricity
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/acronyms
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/changes_in_2024
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/aviation
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Natural_Gas
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Hydrogen
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Marine_Fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/comparison_of_ld_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Petro-_and_Bio-Based_Diesel_Fuel
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/definitions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/gasoline_and_ethanol
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/disclaimer
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/light-duty_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/medium-_and_heavy-duty_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/references
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/technical_limitations
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/2023/data
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/acronyms
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/Offshore_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/Land-Based_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/Distributed_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/biopower_(eia)
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/changes_in_2024
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/distributed_wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/equations_&_variables
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024/pv-ac-dc
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/Distributed_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/Land-Based_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/Offshore_Wind
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/2023/data
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/electricity/2024b/pv-ac-dc
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/BOB
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Ethanol
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Diesel_Bio-Based_Blendstock
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Blendstocks
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Gasoline_and_Ethanol
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/aviation_fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/Natural_Gas_Fuel
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/battery_electric
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/battery_electric_vehicle_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/blendstocks
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/battery_electric_mdhd
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/bob
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/comparison_of_mdhd_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/diesel
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/diesel_bio-based_blendstock
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/electricity
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/diesel_hybrid_mdhd
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/diesel_mdhd
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/ethanol
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/fuel_cell_electric_vehicle_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/fuel_cell_mdhd
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/fuel_cell
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/fuel_economy_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/gasoline
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/gasoline_hybrid
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/hydrogen
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/levelized_cost_of_driving_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/literature_context_for_ld_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/lowest_co2e_emissions_fuel_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/marine_fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/literature_context_for_mdhd_vehicles
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/natural_gas
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/natural_gas_fuel
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/on-road_fuels
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/plug-in_hybrid
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/plug-in_hybrid_mdhd
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/petro-_and_bio-based_diesel_fuel
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/production_volume_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/sustainable_aviation_fuel_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/vehicle_range_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# DEBUG:elm.web.website_crawl:Crawled https://atb.nrel.gov/transportation/2024/vehicle_size_class_assumptions
# DEBUG:elm.web.website_crawl:Document passed validation check
# INFO:elm.web.website_crawl:Crawled 141 pages
# INFO:elm.web.website_crawl:Found 141 potential documents
# DEBUG:elm.web.website_crawl:Average score: 0.99
# DEBUG:elm.web.website_crawl:Pages crawled by depth:
# DEBUG:elm.web.website_crawl:  Depth 0: 1 pages
# DEBUG:elm.web.website_crawl:  Depth 1: 13 pages
# DEBUG:elm.web.website_crawl:  Depth 2: 70 pages
# DEBUG:elm.web.website_crawl:  Depth 3: 57 pages

# %% [markdown]
# Now that the crawl is finished, we can examine the documents we extracted

# %%
len(atb_info)
# Out:
# 141

# %%
for doc in atb_info[:5]:
    print(doc)
# Out:
# HTMLDocument with 1 pages
# Attrs:
#                         source:	https://atb.nrel.gov/archive
#   website_link_relevance_score:	1
# HTMLDocument with 1 pages
# Attrs:
#                         source:	https://atb.nrel.gov/search
#   website_link_relevance_score:	1
# HTMLDocument with 1 pages
# Attrs:
#                         source:	https://atb.nrel.gov/electricity/2024b/about
#   website_link_relevance_score:	1
# HTMLDocument with 1 pages
# Attrs:
#                         source:	https://atb.nrel.gov/contact
#   website_link_relevance_score:	1
# HTMLDocument with 1 pages
# Attrs:
#                         source:	https://atb.nrel.gov/transportation/2024/about
#   website_link_relevance_score:	1

# %%
print(atb_info[20].attrs["source"])
print(atb_info[20].text)
# Out:
# https://atb.nrel.gov/electricity/2024/nuclear
# [Skip to main content](https://atb.nrel.gov/electricity/2024/nuclear#content) You are viewing an older version of the ATB. The most recent version of this page is for [_2024b_](https://atb.nrel.gov/electricity/2024b/nuclear). [ ](https://www.nlr.gov "Visit the National Laboratory of the Rockies Homepage") [Annual Technology Baseline](https://atb.nrel.gov/) Menu * [ Electricity ](https://atb.nrel.gov/electricity/2024/nuclear) * [ Electricity ](https://atb.nrel.gov/electricity/2024b/index) * [About](https://atb.nrel.gov/electricity/2024b/about) * [Technologies](https://atb.nrel.gov/electricity/2024b/technologies) * [Data](https://atb.nrel.gov/electricity/2024b/data) * [ Transportation ](https://atb.nrel.gov/electricity/2024/nuclear) * [ Transportation ](https://atb.nrel.gov/transportation/2024/index) * [About](https://atb.nrel.gov/transportation/2024/about) * [Technologies](https://atb.nrel.gov/transportation/2024/technologies) * [Data](https://atb.nrel.gov/transportation/2024/data) * [ Contact](https://atb.nrel.gov/electricity/2024/nuclear) * [Contact Us](https://atb.nrel.gov/contact) * [Register for Updates](https://atb.nrel.gov/register) * [Archive](https://atb.nrel.gov/archive) * [ ](https://atb.nrel.gov/search) * [Login](https://atb.nrel.gov/login) # Nuclear ![](https://atb.nrel.gov/img/other/tableau-animated-loader.png) 2024 ATB data for advanced nuclear energy are shown above. These projections are based on a compilation of historical and recent cost estimates for various advanced nuclear energy technologies as well as historical U.S. costs for nuclear plant construction. The data include 35 bottom-up, detailed cost estimations for the reactors along with two data sets compiling historical observed U.S. costs for nuclear power plants. Values were mapped, escalated, and processed to ensure a suitable cross-comparison baseline between detailed estimates. Given the timeline for U.S. new reactor commercial demonstrations to start operations, the cost estimates provided start in 2030. This is primarily based on the timeline for U.S. Department of Energy (DOE) advanced reactor demonstration program reactors, which are expected to be complete near 2030. As such, the cost ranges are not for so-called "first-of-a-kind" (FOAK) but rather for "next commercial offerings" (or "between first- and Nth-of-a-kind [NOAK]"). The cost estimates are technology-agnostic, but distinctions between large (1,000 MWe) and small (300 MWe) reactors (often called small modular reactors, or SMRs) are made. Additional detail on the methodology for providing the estimates is provided in [(Abou-Jaoude et al., 2024)](https://atb.nrel.gov/electricity/2024/nuclear#PL7EJT85). The evolution in cost estimates over the duration considered is primarily driven by better project execution and experienced gained in deploying standardized reactor designs. Estimates for operating costs for large reactors are mainly derived from experience with the current fleet of nuclear power plants. Estimates for SMRs are based on a compilation of bottom-up historical data sets in a similar fashion to the capital expenses. The writeup here leans heavily on [(Abou-Jaoude et al., 2024)](https://atb.nrel.gov/electricity/2024/nuclear#PL7EJT85). To help guide readers to the relevant sections of the report for additional information, the following outline is provided: * Section 3: Overview of data sets leveraged from literature. * Section 4: Mapping methodology and cost escalation. * Section 5: Processing of capital cost estimates. This section also includes information on multi-unit plant impacts, recommended groupings, construction timelines, reactor lifetime, capacity factor, and ramp rates. * Section 6: Operation and Maintenance Costs. * Section 7: Nuclear deployment projections, learning rates, and cost reduction over time. * Section 8: Impact of subsidies, coal-to-nuclear transition, and non-electric nuclear applications. Future work will continue to refine the data sets provided h ...

# %% [markdown]
# ### Practice
# Here are a few things you can do to expand upon this tutorial and gain some practice setting up a website crawler:
#
# - Exclude duplicated content (either URL filter or document filter)
# - Filter out documents with "Page not found" text
# - Search only electricity ATB
# - Prioritize links that go into definitions, documentation, and methods
# - Post-process documents (filter out markdown syntax, chunk text, compute embeddings, store in database, etc)
#
# <br>

# %% [markdown]
# ## 2. Advanced: Targeted 2024 ATB Crawl
#
# In this example, we'll build on the crawler we set up in the first part of this tutorial, except we'll expand it to be more targeted in it's search. In particular, we'll leverage LLM's to parse the website content to check for specific information about geothermal well flow rates.
#
# We'll start by setting up the URL filter as before:

# %%
class ATBFilter(URLFilter):
    """Helper class to filter url's down to ATB website"""

    def apply(self, url):
        """Check if the URL is part of the ATB website.

        Specifically, we check for the full subdomain (https://atb.nrel.gov)
        in the URL. We also check that if a year is "detected" in the URL,
        that it is the 2024 ATB year. Finally, we check that the URL
        does not contain a section link (i.e., it does not contain a `#`).
        For example, these links

        https://atb.nrel.gov/electricity/2024/index/definitions#financialcases
        https://atb.nrel.gov/electricity/2024/index/definitions#r&donlycase

        are just the same link but pointing to different sections of the
        page. Thus, checking for "#" helps avoid collecting redundant
        information.
        """
        correct_subdomain = url.casefold().startswith("https://atb.nrel.gov")
        correct_year = True if "/20" not in url else "/2024" in url
        not_subsection_link = "#" not in url
        return correct_subdomain and correct_year and not_subsection_link

# %% [markdown]
# However, for the document validator, we'll apply an LLM to examine the website text:

# %%
from elm.ords.llm import LLMCaller
from elm.ords.services.openai import OpenAIService

SYSTEM_MESSAGE = (
    "You examine text scraped form the NLR ATB website to determine if it "
    "contains information relevant to the user's query. Base your responses "
    "only off of the content of the webpage and **not** on any auxiliary "
    "information."
)
INSTRUCTIONS = (
    "Does the text from this website give specifics about the flow rate per "
    "production well used in a geothermal 2024 ATB scenario? "
    "Begin your response with 'Yes' or 'No', briefly explain your answer, "
    "and end your response with the production well flow rate value you found."
)
LLM = LLMCaller(llm_service=OpenAIService, model="gpt-4o-mini")


async def llm_geothermal_validator(doc):
    """Apply an LLM to check for flow rate text."""
    question = f"{INSTRUCTIONS}\n\nText:\n\n{doc.text}"
    llm_response = await LLM.call(sys_msg=SYSTEM_MESSAGE, content=question)
    return llm_response.casefold().startswith("yes")

# %% [markdown]
# We'll also assume that once a single document is found, we have the info we need so we can stop the search:

# %%
async def single_doc_terminator(docs):
    """Assume that once a website passes validation that we can stop crawl."""
    return len(docs) > 0

# %% [markdown]
# To try to minimize LLM costs, let's also prioritize any links that mention geothermal:

# %%
async def geothermal_link_scorer(links):
    """Prioritize any web links that mention 'geothermal'."""
    for link in links:
        link_title_text = link.get("text", "")
        link_url = link.get("href", "")
        base_score = 1
        if ("geothermal" in link_title_text.casefold()
            or "geothermal" in link_url.casefold()):
            base_score = 2

        link["score"] = base_score

    return links

# %% [markdown]
# Now we can set up crawling as before (note that we use the new validator and link scorer):

# %%
crawler = ELMWebsiteCrawler(llm_geothermal_validator,
                            async_file_loader=afl,
                            extra_url_filters=[ATBFilter()],
                            url_scorer=geothermal_link_scorer,
                            crawl_strategy_kwargs={"max_depth": 3},
                            max_pages=1000)

# %% [markdown]
# The only difference this time is that we have to launch the LLM service before we execute the crawl:

# %%
import openai
from elm.utilities import validate_azure_api_params
from elm.ords.services.provider import RunningAsyncServices

# func below assumes you have API params set as ENV variables
azure_api_key, azure_version, azure_endpoint = validate_azure_api_params()
client = openai.AsyncAzureOpenAI(
    api_key=azure_api_key,
    api_version=azure_version,
    azure_endpoint=azure_endpoint,
)
services = [OpenAIService(client, rate_limit=500_000)]
async with RunningAsyncServices(services):
    geo_info = await crawler.run("https://atb.nrel.gov/",
                                 termination_callback=single_doc_terminator)

# %%
geo_info

# %% [markdown]
# ### Practice
# Here are a few things you can do to expand upon this tutorial and gain some practice setting up a more advanced website crawler:
#
# - Set up a decision tree with more specific content filtering using the LLM
# - Score the links using an LLM
#
# <br>
